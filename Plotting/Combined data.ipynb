# %%
import pandas as pd

# %%
altnews_df = pd.read_csv('altnews_df.csv')
altnews_df
# Out:
#                                                    url  \
# 0    https://www.altnews.in/no-the-elderly-man-pelt...
# 1    https://www.altnews.in/caa-protest-video-of-ja...
# 2    https://www.altnews.in/no-danish-kaneria-is-no...
# 3    https://www.altnews.in/video-from-sri-lanka-sh...
# 4    https://www.altnews.in/caa-protests-old-video-...
# ..                                                 ...
# 358  https://www.altnews.in/delhi-police-supporting...
# 359  https://www.altnews.in/shaheen-bagh-women-gett...
# 360  https://www.altnews.in/muslim-shop-sells-birya...
# 361  https://www.altnews.in/muslim-girl-raped-by-hi...
# 362  https://www.altnews.in/suresh-chawanke-shared-...
#
#                                               headline  datetime organization  \
# 0    No, the elderly man pelting stone in Kanpur is...  12/31/19     Alt News
# 1    CAA Protest: Video of Jabalpur police vandalis...  12/31/19     Alt News
# ...

# %%
altnews_df.dtypes
# Out:
# url             object
# headline        object
# datetime        object
# organization    object
# caa             object
# dtype: object

# %%
altnews_df['datetime'] = pd.to_datetime(altnews_df['datetime'])

# %%
altnews_df.dtypes
# Out:
# url                     object
# headline                object
# datetime        datetime64[ns]
# organization            object
# caa                     object
# dtype: object

# %%
altnews_df['datetime'] = altnews_df['datetime'].dt.strftime('%m-%d-%Y')
altnews_df
# Out:
#                                                    url  \
# 0    https://www.altnews.in/no-the-elderly-man-pelt...
# 1    https://www.altnews.in/caa-protest-video-of-ja...
# 2    https://www.altnews.in/no-danish-kaneria-is-no...
# 3    https://www.altnews.in/video-from-sri-lanka-sh...
# 4    https://www.altnews.in/caa-protests-old-video-...
# ..                                                 ...
# 358  https://www.altnews.in/delhi-police-supporting...
# 359  https://www.altnews.in/shaheen-bagh-women-gett...
# 360  https://www.altnews.in/muslim-shop-sells-birya...
# 361  https://www.altnews.in/muslim-girl-raped-by-hi...
# 362  https://www.altnews.in/suresh-chawanke-shared-...
#
#                                               headline    datetime  \
# 0    No, the elderly man pelting stone in Kanpur is...  12-31-2019
# 1    CAA Protest: Video of Jabalpur police vandalis...  12-31-2019
# 2    No, Danish Kaneria is not among Pakistani play...  12-30-2019
# ...

# %%
boom_df = pd.read_csv('boom_df.csv')
boom_df
# Out:
#                                                    url  \
# 0    https://www.boomlive.in/health/does-drinking-a...
# 1    https://www.boomlive.in/false-suicide-attempt-...
# 2    https://www.boomlive.in/world/can-drinking-bub...
# 3    https://www.boomlive.in/boom-reports/saudi-wom...
# 4    https://www.boomlive.in/health/false-coronavir...
# ..                                                 ...
# 200  https://www.boomlive.in/world/coronavirus/aust...
# 201  https://www.boomlive.in/fake-news/did-pm-modi-...
# 202  https://www.boomlive.in/coronavirus-outbreak/d...
# 203  https://www.boomlive.in/fake-news/viral-post-c...
# 204  https://www.boomlive.in/fake-news/picture-show...
#
#                                               headline  datetime organization  \
# 0           Does Drinking Alcohol Prevent Coronavirus?   2/19/20     Boomlive
# 1    False: Suicide Attempt Over Government's LIC S...    2/3/20     Boomlive
# ...

# %%
boom_df['datetime'] = pd.to_datetime(boom_df['datetime'])

# %%
boom_df.dtypes
# Out:
# url                     object
# headline                object
# datetime        datetime64[ns]
# organization            object
# caa                     object
# dtype: object

# %%
boom_df['datetime'] = boom_df['datetime'].dt.strftime('%m-%d-%Y')

# %%
quint_df = pd.read_csv('quint_df.csv')
quint_df
# Out:
#                                                    url  \
# 0    https://www.thequint.com/news/webqoof/nirbhaya...
# 1    https://www.thequint.com/news/webqoof/italy-pr...
# 2    https://www.thequint.com/news/webqoof/assam-de...
# 3    https://www.thequint.com/news/webqoof/dettol-p...
# 4    https://www.thequint.com/news/webqoof/rss-peop...
# ..                                                 ...
# 140  https://www.thequint.com/news/webqoof/girl-mad...
# 141  https://www.thequint.com/news/webqoof/bjp-mla-...
# 142  https://www.thequint.com/news/webqoof/image-of...
# 143  https://www.thequint.com/news/webqoof/video-cl...
# 144  https://www.thequint.com/news/webqoof/fake-cla...
#
#                                               headline  datetime  \
# 0    Don’t Call This Old Nirbhaya Helpline Going Vi...   12/2/19
# 1    No, This Isn’t the Italian President Crying Ov...   3/23/20
# 2    Images of Detention Camps in US, La Romana Sha...  12/16/19
# ...

# %%
quint_df.dtypes
# Out:
# url                   object
# headline              object
# datetime              object
# fact_check_details    object
# organization          object
# caa                   object
# dtype: object

# %%
quint_df['datetime'] = pd.to_datetime(quint_df['datetime'])

# %%
quint_df.dtypes
# Out:
# url                           object
# headline                      object
# datetime              datetime64[ns]
# fact_check_details            object
# organization                  object
# caa                           object
# dtype: object

# %%
quint_df['datetime'] = quint_df['datetime'].dt.strftime('%m-%d-%Y')

# %%
vishvasnews_df = pd.read_csv('vishvas_news_df.csv')
vishvasnews_df
# Out:
#                                                    url  \
# 0    https://www.vishvasnews.com/politics/rahul-gan...
# 1    https://www.vishvasnews.com/viral/fact-check-f...
# 2    https://www.vishvasnews.com/viral/fact-check-t...
# 3    https://www.vishvasnews.com/politics/quick-fac...
# 4    https://www.vishvasnews.com/english/health/fac...
# ..                                                 ...
# 107  https://www.vishvasnews.com/english/politics/f...
# 108  https://www.vishvasnews.com/politics/fact-chec...
# 109  https://www.vishvasnews.com/english/health/fac...
# 110  https://www.vishvasnews.com/world/fact-check-a...
# 111  https://www.vishvasnews.com/politics/quick-fac...
#
#                                               headline   datetime  \
# 0    Fact Check : नागरिकता संशोधन विधेयक पर राहुल ग...  11-Dec-19
# 1    Fact Check: हिमालया कंपनी के सीईओ की तस्वीर गल...  18-Mar-20
# 2    Fact Check: हवा में तैरती चट्टान की यह तस्वीर ...   9-Dec-19
# ...

# %%
vishvasnews_df['datetime'] = pd.to_datetime(vishvasnews_df['datetime'])
vishvasnews_df
# Out:
#                                                    url  \
# 0    https://www.vishvasnews.com/politics/rahul-gan...
# 1    https://www.vishvasnews.com/viral/fact-check-f...
# 2    https://www.vishvasnews.com/viral/fact-check-t...
# 3    https://www.vishvasnews.com/politics/quick-fac...
# 4    https://www.vishvasnews.com/english/health/fac...
# ..                                                 ...
# 107  https://www.vishvasnews.com/english/politics/f...
# 108  https://www.vishvasnews.com/politics/fact-chec...
# 109  https://www.vishvasnews.com/english/health/fac...
# 110  https://www.vishvasnews.com/world/fact-check-a...
# 111  https://www.vishvasnews.com/politics/quick-fac...
#
#                                               headline   datetime  \
# 0    Fact Check : नागरिकता संशोधन विधेयक पर राहुल ग... 2019-12-11
# 1    Fact Check: हिमालया कंपनी के सीईओ की तस्वीर गल... 2020-03-18
# 2    Fact Check: हवा में तैरती चट्टान की यह तस्वीर ... 2019-12-09
# ...

# %%
vishvasnews_df['datetime'] = vishvasnews_df['datetime'].dt.strftime('%m-%d-%Y')
vishvasnews_df
# Out:
#                                                    url  \
# 0    https://www.vishvasnews.com/politics/rahul-gan...
# 1    https://www.vishvasnews.com/viral/fact-check-f...
# 2    https://www.vishvasnews.com/viral/fact-check-t...
# 3    https://www.vishvasnews.com/politics/quick-fac...
# 4    https://www.vishvasnews.com/english/health/fac...
# ..                                                 ...
# 107  https://www.vishvasnews.com/english/politics/f...
# 108  https://www.vishvasnews.com/politics/fact-chec...
# 109  https://www.vishvasnews.com/english/health/fac...
# 110  https://www.vishvasnews.com/world/fact-check-a...
# 111  https://www.vishvasnews.com/politics/quick-fac...
#
#                                               headline    datetime  \
# 0    Fact Check : नागरिकता संशोधन विधेयक पर राहुल ग...  12-11-2019
# 1    Fact Check: हिमालया कंपनी के सीईओ की तस्वीर गल...  03-18-2020
# 2    Fact Check: हवा में तैरती चट्टान की यह तस्वीर ...  12-09-2019
# ...

# %%
vishvasnews_df.dtypes
# Out:
# url                   object
# headline              object
# datetime              object
# fact_check_details    object
# organization          object
# caa                   object
# dtype: object

# %%
afp_df = pd.read_csv('afp_df.csv')
afp_df = afp_df.dropna()
afp_df
# Out:
#                                                   url  \
# 0   https://factcheck.afp.com//video-does-not-show...
# 1   https://factcheck.afp.com//video-shows-police-...
# 2   https://factcheck.afp.com//us-president-donald...
# 3   https://factcheck.afp.com//indian-health-autho...
# 4   https://factcheck.afp.com//indian-authorities-...
# 6   https://factcheck.afp.com//afp-photo-taken-dur...
# 7   https://factcheck.afp.com//afp-photo-policeman...
# 8   https://factcheck.afp.com//experts-india-refut...
# 9   https://factcheck.afp.com//indian-health-autho...
# 10  https://factcheck.afp.com//indian-health-autho...
# 11  https://factcheck.afp.com//video-shows-workmen...
# 12  https://factcheck.afp.com//2015-reuters-photo-...
# 13  https://factcheck.afp.com//1998-associated-pre...
# 14  https://factcheck.afp.com//footage-has-been-ta...
# 15  https://factcheck.afp.com//photo-shah-rukh-kha...
# 16  https://factcheck.afp.com//old-photo-was-taken...
# ...

# %%
afp_df['datetime'] = pd.to_datetime(afp_df['datetime'])

# %%
afp_df.dtypes
# Out:
# url                           object
# headline                      object
# datetime              datetime64[ns]
# fact_check_details            object
# organization                  object
# caa                           object
# dtype: object

# %%
indiatoday_df = pd.read_csv('india_today_df.csv')
indiatoday_df
# Out:
#                                                    url  \
# 0    https://www.indiatoday.in/fact-check/story/sha...
# 1    https://www.indiatoday.in/fact-check/story/tas...
# 2    https://www.indiatoday.in/fact-check/story/fac...
# 3    https://www.indiatoday.in/fact-check/story/fak...
# 4    https://www.indiatoday.in/fact-check/story/fac...
# ..                                                 ...
# 121  https://www.indiatoday.in/fact-check/story/fac...
# 122  https://www.indiatoday.in/fact-check/story/fac...
# 123  https://www.indiatoday.in/fact-check/story/fac...
# 124  https://www.indiatoday.in/fact-check/story/fac...
# 125  https://www.indiatoday.in/fact-check/story/fac...
#
#                                               headline  \
# 0    Fact Check: Delhi’s infamous Shahrukh has noth...
# 1    Fact Check: The truth behind police distributi...
# 2    Fact Check: Holding breath for 10 seconds is n...
# 3    Fact Check: Fake news about DCP’s death in Del...
# ...

# %%
indiatoday_df.datetime
# Out:
# 0      UPDATED: Feb 27, 2020 18:34 IST
# 1       UPDATED: Dec 2, 2019 13:44 IST
# 2      UPDATED: Mar 23, 2020 14:25 IST
# 3      UPDATED: Feb 25, 2020 22:24 IST
# 4      UPDATED: Mar 24, 2020 14:12 IST
#                     ...
# 121    UPDATED: Feb 24, 2020 05:40 IST
# 122    UPDATED: Jan 15, 2020 13:43 IST
# 123    UPDATED: Feb 22, 2020 13:51 IST
# 124     UPDATED: Dec 9, 2019 14:42 IST
# 125     UPDATED: Feb 9, 2020 09:02 IST
# Name: datetime, Length: 126, dtype: object

# %%
import re

# %%
indiatoday_df.datetime = indiatoday_df.datetime.str.replace(r'^\w{7}:\s', '')
indiatoday_df
# Out:
# /var/folders/3x/_wb_w3ys63j7vqmgfcp3xx_w0000gn/T/ipykernel_8000/3175612600.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   indiatoday_df.datetime = indiatoday_df.datetime.str.replace(r'^\w{7}:\s', '')
#                                                    url  \
# 0    https://www.indiatoday.in/fact-check/story/sha...
# 1    https://www.indiatoday.in/fact-check/story/tas...
# 2    https://www.indiatoday.in/fact-check/story/fac...
# 3    https://www.indiatoday.in/fact-check/story/fak...
# 4    https://www.indiatoday.in/fact-check/story/fac...
# ..                                                 ...
# 121  https://www.indiatoday.in/fact-check/story/fac...
# 122  https://www.indiatoday.in/fact-check/story/fac...
# 123  https://www.indiatoday.in/fact-check/story/fac...
# 124  https://www.indiatoday.in/fact-check/story/fac...
# 125  https://www.indiatoday.in/fact-check/story/fac...
#
# ...

# %%
indiatoday_df.datetime
# Out:
# 0      Feb 27, 2020 18:34 IST
# 1       Dec 2, 2019 13:44 IST
# 2      Mar 23, 2020 14:25 IST
# 3      Feb 25, 2020 22:24 IST
# 4      Mar 24, 2020 14:12 IST
#                 ...
# 121    Feb 24, 2020 05:40 IST
# 122    Jan 15, 2020 13:43 IST
# 123    Feb 22, 2020 13:51 IST
# 124     Dec 9, 2019 14:42 IST
# 125     Feb 9, 2020 09:02 IST
# Name: datetime, Length: 126, dtype: object

# %%
indiatoday_df.datetime = indiatoday_df.datetime.str.replace(r'\s\d{2}:\d{2}\s\w{3}$', '')
indiatoday_df
# Out:
# /var/folders/3x/_wb_w3ys63j7vqmgfcp3xx_w0000gn/T/ipykernel_8000/938488346.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   indiatoday_df.datetime = indiatoday_df.datetime.str.replace(r'\s\d{2}:\d{2}\s\w{3}$', '')
#                                                    url  \
# 0    https://www.indiatoday.in/fact-check/story/sha...
# 1    https://www.indiatoday.in/fact-check/story/tas...
# 2    https://www.indiatoday.in/fact-check/story/fac...
# 3    https://www.indiatoday.in/fact-check/story/fak...
# 4    https://www.indiatoday.in/fact-check/story/fac...
# ..                                                 ...
# 121  https://www.indiatoday.in/fact-check/story/fac...
# 122  https://www.indiatoday.in/fact-check/story/fac...
# 123  https://www.indiatoday.in/fact-check/story/fac...
# 124  https://www.indiatoday.in/fact-check/story/fac...
# 125  https://www.indiatoday.in/fact-check/story/fac...
#
# ...

# %%
indiatoday_df.datetime = pd.to_datetime(indiatoday_df.datetime)
indiatoday_df
# Out:
#                                                    url  \
# 0    https://www.indiatoday.in/fact-check/story/sha...
# 1    https://www.indiatoday.in/fact-check/story/tas...
# 2    https://www.indiatoday.in/fact-check/story/fac...
# 3    https://www.indiatoday.in/fact-check/story/fak...
# 4    https://www.indiatoday.in/fact-check/story/fac...
# ..                                                 ...
# 121  https://www.indiatoday.in/fact-check/story/fac...
# 122  https://www.indiatoday.in/fact-check/story/fac...
# 123  https://www.indiatoday.in/fact-check/story/fac...
# 124  https://www.indiatoday.in/fact-check/story/fac...
# 125  https://www.indiatoday.in/fact-check/story/fac...
#
#                                               headline   datetime  \
# 0    Fact Check: Delhi’s infamous Shahrukh has noth... 2020-02-27
# 1    Fact Check: The truth behind police distributi... 2019-12-02
# 2    Fact Check: Holding breath for 10 seconds is n... 2020-03-23
# ...

# %%
indiatoday_df['datetime'] = indiatoday_df['datetime'].dt.strftime('%m-%d-%Y')

# %%
indiatoday_df.datetime
# Out:
# 0      02-27-2020
# 1      12-02-2019
# 2      03-23-2020
# 3      02-25-2020
# 4      03-24-2020
#           ...
# 121    02-24-2020
# 122    01-15-2020
# 123    02-22-2020
# 124    12-09-2019
# 125    02-09-2020
# Name: datetime, Length: 126, dtype: object

# %%
df_main = pd.concat([altnews_df, boom_df, quint_df, vishvasnews_df, afp_df, indiatoday_df], axis=0)
df_main.sample(40)
# Out:
#                                                    url  \
# 235  https://www.altnews.in/old-video-from-rajastha...
# 68   https://www.indiatoday.in/fact-check/story/fac...
# 81   https://www.vishvasnews.com/politics/fact-chec...
# 95   https://www.indiatoday.in/fact-check/story/fac...
# 217  https://www.altnews.in/jamia-violence-media-mi...
# 101  https://www.altnews.in/caa-protests-video-of-i...
# 118  https://www.indiatoday.in/fact-check/story/fac...
# 35   https://www.boomlive.in/world/coronavirus/coro...
# 113  https://www.boomlive.in/fake-news/video-of-con...
# 20   https://www.vishvasnews.com/viral/fact-check-v...
# 2    https://www.boomlive.in/world/can-drinking-bub...
# 80   https://www.indiatoday.in/fact-check/story/fac...
# 51   https://www.vishvasnews.com/viral/fact-check-1...
# 20   https://www.thequint.com/news/webqoof/amit-sha...
# 218  https://www.altnews.in/jamia-violence-student-...
# 37   https://www.boomlive.in/fake-news/false-passen...
# ...

# %%
df_main = df_main.reset_index(drop=True)
df_main.sample(20)
# Out:
#                                                    url  \
# 3    https://www.altnews.in/video-from-sri-lanka-sh...
# 403  https://www.boomlive.in/fake-news/cannot-lathi...
# 157  https://www.altnews.in/bjp-mla-himanta-biswa-p...
# 395  https://www.boomlive.in/world/coronavirus/misl...
# 537  https://www.boomlive.in/fact-file/hantavirus-f...
# 102  https://www.altnews.in/no-homeopathic-drug-ars...
# 156  https://www.altnews.in/video-from-2018-shared-...
# 85   https://www.altnews.in/no-the-accused-in-hyder...
# 562  https://www.boomlive.in/fake-news/hate-me-but-...
# 421  https://www.boomlive.in/fake-news/coronavirus-...
# 896  https://www.indiatoday.in/fact-check/story/fac...
# 691  https://www.thequint.com/news/webqoof/mp-girl-...
# 401  https://www.boomlive.in/fact-file/hyderabad-en...
# 560  https://www.boomlive.in/fake-news/2015-photo-f...
# 124  https://www.altnews.in/old-unrelated-video-vir...
# 761  https://www.vishvasnews.com/english/health/fac...
# ...

# %%
df_main.datetime = pd.to_datetime(df_main.datetime)

# %%
df_main.dtypes
# Out:
# url                           object
# headline                      object
# datetime              datetime64[ns]
# organization                  object
# caa                           object
# fact_check_details            object
# dtype: object

# %%
df_main.to_csv('combined_date.csv', index=False)

# %% [markdown]
# # Plotting

# %%
# how many articles were published in each months?
df_main.datetime.dt.month.value_counts()
# Out:
# 3     308
# 12    231
# 1     223
# 2     207
# Name: datetime, dtype: int64

# %%
# why are there four articles in Nov when the timeframe is Dec to March? Let's find out

nov = df_main['datetime'].dt.month == 11
november_urls = df_main['url'][nov]
november_urls
# Out:
# Series([], Name: url, dtype: object)

# %%
# I'm not sure how this has happened and it's difficult to find out
# An easier way is to remove these urls from the afp_df.csv

# %%
df_main.dtypes
# Out:
# url                           object
# headline                      object
# datetime              datetime64[ns]
# organization                  object
# caa                           object
# fact_check_details            object
# dtype: object

# %%
df_main[df_main.caa == 'Yes'].organization.value_counts()
# Out:
# Alt News        148
# Boomlive         44
# The Quint        39
# India Today      19
# Vishvas News      8
# AFP               3
# Name: organization, dtype: int64

# %% [markdown]
# ### Plot by value count

# %%
df_main[df_main.caa == 'Yes'].organization.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
# .unstack puts the data into a dataframe

df_main[df_main.caa == 'Yes'].resample('M', on='datetime').organization.value_counts().unstack()
# Out:
# organization  AFP  Alt News  Boomlive  India Today  The Quint  Vishvas News
# datetime
# 2019-12-31    1.0      50.0      14.0          6.0       13.0           5.0
# 2020-01-31    NaN      48.0      14.0          5.0       13.0           2.0
# 2020-02-29    NaN      34.0      12.0          5.0        7.0           1.0
# 2020-03-31    2.0      16.0       4.0          3.0        6.0           NaN

# %% [markdown]
# ### Plot by montly count

# %%
df_main[df_main.caa == 'Yes'].resample('M', on='datetime').organization.value_counts().unstack().fillna(0).plot()
# Out:
# <AxesSubplot: xlabel='datetime'>

# %%
# total stories

df_main.resample('M', on='datetime').organization.value_counts().unstack().fillna(0).plot()
# Out:
# <AxesSubplot: xlabel='datetime'>

# %% [markdown]
# ### Plot by month normalized

# %%
df_main[df_main.caa == 'Yes'].resample('M', on='datetime').organization.value_counts(normalize=True).unstack().fillna(0).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='datetime'>

# %%
# can I sort the stacks in area plot? from the largest to smallest?
# tbh not the best way to plot this. line graph maybe better but just wondering

# %%
df_main[df_main.caa == 'Yes'] \
    .resample('M', on='datetime') \
    .organization \
    .value_counts(normalize=True) \
    .unstack() \
    .fillna(0)
# Out:
# organization       AFP  Alt News  Boomlive  India Today  The Quint  \
# datetime
# 2019-12-31    0.011236  0.561798  0.157303     0.067416   0.146067
# 2020-01-31    0.000000  0.585366  0.170732     0.060976   0.158537
# 2020-02-29    0.000000  0.576271  0.203390     0.084746   0.118644
# 2020-03-31    0.064516  0.516129  0.129032     0.096774   0.193548
#
# organization  Vishvas News
# datetime
# 2019-12-31        0.056180
# 2020-01-31        0.024390
# 2020-02-29        0.016949
# 2020-03-31        0.000000
